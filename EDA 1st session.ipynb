# %% [markdown]
# #reading the csv file#

# %%
import pandas as pd # dataframe operations
import numpy as np # math operations
import matplotlib.pyplot as plt # diagram/plots
import seasborn as sns  # diagram/plots

# %%
import pandas as pd
path=r"C:\Users\akash\Python_class_codes\EDA sessions\Visadataset.csv"
df=pd.read_csv(path)
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
path=r"C:\Users\akash\Python_class_codes\EDA sessions\bank.csv"
pd.read_csv(path)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
name=['ramesh','suresh','satish']
age=[30,30,40]
name,age
# Out:
# (['ramesh', 'suresh', 'satish'], [30, 30, 40])

# %%
ind=['1','2','3']
pd.DataFrame(zip(name,age),columns=['name','age'],index=ind)
# Out:
#      name  age
# 1  ramesh   30
# 2  suresh   30
# 3  satish   40

# %%
ind=['1','2','3']
df=pd.DataFrame(zip(name,age),columns=['name','age'],index=ind)
salary= ['2000','2300','5412']
df["sal"]=salary
df
# Out:
#      name  age   sal
# 1  ramesh   30  2000
# 2  suresh   30  2300
# 3  satish   40  5412

# %%
ind=['1','2','3']
df=pd.DataFrame(zip(name,age),columns=['name','age'],index=ind)
salary= ['2000','2300','5412']
df["sal"]=salary
df
# Out:
#      name  age   sal
# 1  ramesh   30  2000
# 2  suresh   30  2300
# 3  satish   40  5412

# %%
df['name']=["vikas","akash","vimal"]
df.drop('2',axis=0,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df['name']=["vikas","akash","vimal"]
#       2 df.drop('2',axis=0,inplace=True)
#       3 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
#    4135     Add series to DataFrame in specified column.
#    4136
#    (...)
#    4141     ensure homogeneity.
#    4142     """
# -> 4143     value = self._sanitize_column(value)
#    4145     if (
#    4146         key in self.columns
#    4147         and value.ndim == 1
# ...

# %%
df.drop(3,axis=0,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df.drop(3,axis=0,inplace=True)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [1, 2, 3]

# %%
df.to_csv("first_output.csv")
df.to_excel("first_output.xlsx")

# %%
path=r"first_output.csv"
pd.read_csv(path)
# Out:
#    Unnamed: 0   name  age   sal
# 0           1  vikas   30  2000
# 1           2  akash   30  2300

# %%
df.to_csv("first_output.csv",index=False)
path=r"first_output.csv"
pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df.to_csv("first_output.csv",index=False)
#       2 path=r"first_output.csv"
#       3 pd.read_csv(path)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
# ...

# %%
df.to_csv("first_output.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df.to_csv("first_output.csv",index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
# ...

# %%
path=r"first_output.csv"
pd.read_csv(path)
# Out:
#    Unnamed: 0   name  age   sal
# 0           1  vikas   30  2000
# 1           2  akash   30  2300
